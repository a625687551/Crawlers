# %%
from bs4 import BeautifulSoup
import requests
import re
import json
from selenium import webdriver

# %%
url='https://www.essencefund.com/mall/views/index.html'
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.101 Safari/537.36'}

# %%
driver=webdriver.PhantomJS(executable_path='D:\\Program Files\\phantomjs-2.1.1-windows\\bin\\phantomjs.exe')
driver.get(url)
soup=BeautifulSoup(driver.page_source,'lxml')

# %%
l=map(lambda s :s.get_text(strip=True),soup.findAll('tr'))

# %%
l=map(lambda s :s.get_text(),soup.findAll('tr'))

# %%
list(l)
# Out:
# ['\n基金代码\n基金名称\n日期\n单位净值\n日涨幅\n近一年涨幅\n申购费率\n操作\n',
#  '\n000577\n\n\n安信价值精选股票\n\n                                                  2016-12-09\n                                         \n\n                                                          2.1940\n\t\t\t\t\t\n\n\n+0.18%\n\n\n\n\n+18.85%\n\n\n\n\n \n 1.50%  \n                             \xa0\xa00.00% \n\n\n \n立即申购\n',
#  '\n000974\n\n\n安信消费医药股票\n\n                                                  2016-12-09\n                                         \n\n                                                          1.1470\n\t\t\t\t\t\n\n\n+0.09%\n\n\n\n\n+13.12%\n\n\n\n\n \n 1.50%  \n                             \xa0\xa00.00% \n\n\n \n立即申购\n',
# ...
